# %%
import numpy as np 
import seaborn 
import matplotlib.pyplot as plt

# %% [markdown]
# **Uniform Distribution**
#
# Used to describe probability where every event has equal chances of occuring.
#
# E.g. Generation of random numbers.
#
# It has three parameters:
#
# **low** - lower bound - default 0 .0.
#
# **high** - upper bound - default 1.0.
#
# **size** - The shape of the returned array.

# %%
print(np.random.uniform(low=1.0, high=10.0, size=(3, 4)))
# Out:
# [[5.10620906 2.24860466 2.92276815 3.38837954]
#  [2.1036024  4.53557494 3.02230674 6.49099401]
#  [4.25685227 5.75834537 1.43806221 9.49389217]]

# %%
seaborn.displot(np.random.uniform(low=10.0, high=50.0, size=1000), kind='kde')
plt.show()
