# %%
from numpy import random
import seaborn
import matplotlib.pyplot as plt

# %% [markdown]
# **Chi Square Distribution**
#
# Chi Square distribution is used as a basis to verify the hypothesis.
#
# It has two parameters:
#
# df - (degree of freedom).
#
# size - The shape of the returned array.

# %%
n = random.chisquare(df=2.0, size=(2, 3))
print(n)
# Out:
# [[9.82998943 2.87166002 0.11943003]
#  [1.24953309 0.06747903 0.52239549]]

# %%
m = random.chisquare(df=5.0, size=1000)
print(m[0:20])
seaborn.displot(m, kind='kde')
plt.show()
# Out:
# [5.26738571 3.33037261 0.68151621 1.89940966 3.01417913 4.30115182
#  1.64384193 9.173513   4.2665147  3.91672725 5.25635927 6.2787538
#  2.70899787 1.92915945 1.372221   5.2833653  4.84262584 2.79166016
#  2.11932226 5.5628365 ]
